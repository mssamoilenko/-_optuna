# %% [markdown]
# <a href="https://colab.research.google.com/github/mssamoilenko/-_optuna/blob/main/%D0%A1%D0%B0%D0%BC%D0%BE%D0%B9%D0%BB%D0%B5%D0%BD%D0%BA%D0%BE_%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BE%D0%BC%D0%BF%D1%8E%D1%82%D0%B5%D1%80%D0%BD%D0%B8%D0%B9_%D0%B7%D1%96%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1
#
# Зробіть сегментацію для наступного зображення https://github.com/HalyshAnton/IT-Step-Pyton-AI/blob/main/module5/images/cat.jpg
#
# * завантежте модель `deeplabv3_resnet50` та відповідні ваги `DeepLabV3_ResNet50_Weights` [документація](https://pytorch.org/vision/stable/models/generated/torchvision.models.segmentation.deeplabv3_resnet50.html#deeplabv3-resnet50)
# * застосуйте `transforms.Resize` до зображення
# * застосуйте `transforms` з ваг до зображення
# * змініть розмірність зображення на потрібну
# * отримайте результат моделі
# * застосуйте `draw_segmentation_masks`

# %% [markdown]
# # Завдання 2
#
# Проведіть виявлення об'єктів на даному зображенні https://www.thespruce.com/thmb/o_zAsNy0xWNWeq9xfWwAo6fhueo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/SPR-luxury-kitchens-5211364-hero-688d716970544978bc12abdf17ce6f83.jpg
#
# * Підберіть різні параметри `conf` та `iou` щоб подивитись на результат роботи моделі
# * За допомогою параметра `classes` визначіть на зображенні лише:
#   1. стільці
#   2. бокали для вина
#   3. рослини та вази

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.3 MB/s eta 0:00:00

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = ultralytics.YOLO('yolo11n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 50.1MB/s]

# %%
results = model.predict(source='https://www.thespruce.com/thmb/o_zAsNy0xWNWeq9xfWwAo6fhueo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/SPR-luxury-kitchens-5211364-hero-688d716970544978bc12abdf17ce6f83.jpg',
              conf = 0.45,
              iou = 0.05,
              classes =[40, 56, 58, 75], imgsz = 980)
# Out:
# WARNING ⚠️ imgsz=[980] must be multiple of max stride 32, updating to [992]
# Found https://www.thespruce.com/thmb/o_zAsNy0xWNWeq9xfWwAo6fhueo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/SPR-luxury-kitchens-5211364-hero-688d716970544978bc12abdf17ce6f83.jpg locally at SPR-luxury-kitchens-5211364-hero-688d716970544978bc12abdf17ce6f83.jpg
# image 1/1 /content/SPR-luxury-kitchens-5211364-hero-688d716970544978bc12abdf17ce6f83.jpg: 672x992 4 wine glasss, 3 chairs, 2 potted plants, 2 vases, 320.0ms
# Speed: 7.4ms preprocess, 320.0ms inference, 1.9ms postprocess per image at shape (1, 3, 672, 992)

# %%
results_dict = results[0].names

# %%
target_classes = ['chair' ,'wine glass','potted plant', 'vase']

# %%
for id, name in results_dict.items():
  if name in target_classes:
    print({name},{id})
# Out:
# {'wine glass'} {40}
# {'chair'} {56}
# {'potted plant'} {58}
# {'vase'} {75}

# %%
foto_array = results[0].plot()

# %%
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 15))
# plt.imshow(foto_array)

# %%
foto_array.shape
# Out:
# (1000, 1500, 3)

# %%
plt.figure(figsize=(10, 15))
plt.imshow(foto_array[:, :,  ::-1])

# %%
results[0].boxes[10]
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([75.])
# conf: tensor([0.4946])
# data: tensor([[3.2240e+02, 4.5576e+02, 3.8281e+02, 5.5266e+02, 4.9462e-01, 7.5000e+01]])
# id: None
# is_track: False
# orig_shape: (1000, 1500)
# shape: torch.Size([1, 6])
# xywh: tensor([[352.6014, 504.2103,  60.4118,  96.9091]])
# xywhn: tensor([[0.2351, 0.5042, 0.0403, 0.0969]])
# xyxy: tensor([[322.3955, 455.7557, 382.8073, 552.6649]])
# xyxyn: tensor([[0.2149, 0.4558, 0.2552, 0.5527]])

# %%
x1, y1, x2, y2 = results[0].boxes[10].xyxy[0]

# %%
listX = [x1, y1, x2, y2]

x1, y1, x2, y2 = map(int, listX)

# %%
x1, y1, x2, y2
# Out:
# (322, 455, 382, 552)

# %%
plt.figure(figsize=(10, 15))
plt.imshow(foto_array[y1:y2, x1:x2, ::-1])
